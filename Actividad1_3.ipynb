# %% [markdown]
# Aremy Díaz Cárcamo - A01552123

# %%
#Importar librerías
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('Inmuebles.xlsx',header=1)
df.head()
# Out:
#    Referencia Fecha_Alta     Tipo Operación  Provincia  Superficie  \
# 0           1 2004-01-01  Parking  Alquiler     Lleida       291.0
# 1           2 2004-01-01    Local     Venta     Girona       185.0
# 2           3 2004-01-01  Oficina  Alquiler     Girona        82.0
# 3           4 2004-01-02  Parking  Alquiler     Girona       285.0
# 4           5 2004-01-02    Suelo     Venta  Tarragona       152.0
#
#    Precio Venta Fecha Venta Vendedor
# 0     2133903.0  2004-06-19   Carmen
# 1     1945424.0  2004-04-19    Pedro
# 2           NaN  2004-11-08  Joaquín
# 3           NaN  2004-04-27    Jesús
# 4      185000.0  2004-07-10    María

# %%
#Aplicar los siguientes filtros
#Filtro A: Eliminar la fila "0" de "Unnamed" y eliminar la columna "0" y la columna "Referencia"
filtro_a=df.drop('Referencia', axis=1)
filtro_a
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 0    2004-01-01     Parking  Alquiler     Lleida       291.0     2133903.0
# 1    2004-01-01       Local     Venta     Girona       185.0     1945424.0
# 2    2004-01-01     Oficina  Alquiler     Girona        82.0           NaN
# 3    2004-01-02     Parking  Alquiler     Girona       285.0           NaN
# 4    2004-01-02       Suelo     Venta  Tarragona       152.0      185000.0
# ...         ...         ...       ...        ...         ...           ...
# 3332 2007-04-29  Industrial  Alquiler     Lleida       221.0     1450644.0
# 3333 2007-04-29        Piso  Alquiler     Girona        55.0      454080.0
# 3334 2007-04-30       Suelo     Venta  Tarragona        78.0      740688.0
# 3335 2007-04-30        Piso  Alquiler  Barcelona        88.0      397408.0
# 3336 2007-04-30     Parking     Venta     Lleida       254.0     2140712.0
#
#      Fecha Venta Vendedor
# 0     2004-06-19   Carmen
# ...

# %%
#Los siguientes filtros son sobre filtro_a
#Filtro b: "Fecha_Alta" igual a 2007-04-29 y a 2004-01-02
filtro_b=filtro_a[(filtro_a["Fecha_Alta"]=="2007-04-29") | (df["Fecha_Alta"]=="2004-01-02")]
filtro_b
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 3    2004-01-02     Parking  Alquiler     Girona       285.0           NaN
# 4    2004-01-02       Suelo     Venta  Tarragona       152.0      185000.0
# 3331 2007-04-29     Oficina     Venta     Lleida       190.0     1031320.0
# 3332 2007-04-29  Industrial  Alquiler     Lleida       221.0     1450644.0
# 3333 2007-04-29        Piso  Alquiler     Girona        55.0      454080.0
#
#      Fecha Venta Vendedor
# 3     2004-04-27    Jesús
# 4     2004-07-10    María
# 3331         NaT      NaN
# 3332         NaT      NaN
# 3333         NaT      NaN

# %%
#Filtro c: Todos los registros de "Tipo" parking, local, industrial y piso
filtro_c=filtro_a[(filtro_a["Tipo"]=="Parking") | (df["Tipo"]=="Local") | (df["Tipo"]=="Industrial") | (df["Tipo"]=="Piso")]
filtro_c
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 0    2004-01-01     Parking  Alquiler     Lleida       291.0     2133903.0
# 1    2004-01-01       Local     Venta     Girona       185.0     1945424.0
# 3    2004-01-02     Parking  Alquiler     Girona       285.0           NaN
# 5    2004-01-03  Industrial  Alquiler     Girona       131.0      953156.0
# 6    2004-01-03     Parking  Alquiler  Tarragona         NaN      406686.0
# ...         ...         ...       ...        ...         ...           ...
# 3330 2007-04-27       Local     Venta     Girona       110.0      845790.0
# 3332 2007-04-29  Industrial  Alquiler     Lleida       221.0     1450644.0
# 3333 2007-04-29        Piso  Alquiler     Girona        55.0      454080.0
# 3335 2007-04-30        Piso  Alquiler  Barcelona        88.0      397408.0
# 3336 2007-04-30     Parking     Venta     Lleida       254.0     2140712.0
#
#      Fecha Venta Vendedor
# 0     2004-06-19   Carmen
# ...

# %%
#Filtro d: Todos los registros con "Provincia" igual a "Girona" y con "Superficie" mayor a 100
filtro_d=filtro_a[(filtro_a["Provincia"]=="Girona") & (df["Superficie"]>100)]
filtro_d
# Out:
#      Fecha_Alta        Tipo Operación Provincia  Superficie  Precio Venta  \
# 1    2004-01-01       Local     Venta    Girona       185.0     1945424.0
# 3    2004-01-02     Parking  Alquiler    Girona       285.0           NaN
# 5    2004-01-03  Industrial  Alquiler    Girona       131.0      953156.0
# 7    2004-01-03     Oficina     Venta    Girona       235.0     2158475.0
# 10   2004-01-04     Oficina  Alquiler    Girona       124.0      627068.0
# ...         ...         ...       ...       ...         ...           ...
# 3299 2007-04-12       Local  Alquiler    Girona       156.0      881868.0
# 3303 2007-04-12        Piso     Venta    Girona       128.0     1270400.0
# 3306 2007-04-14     Parking     Venta    Girona       221.0     1533077.0
# 3316 2007-04-20        Casa     Venta    Girona       247.0     1804088.0
# 3330 2007-04-27       Local     Venta    Girona       110.0      845790.0
#
#      Fecha Venta Vendedor
# 1     2004-04-19    Pedro
# ...

# %%
#Filtro e: Todos los registros con "Precio Venta" mayor a 1,000,000 o "Vendedor" igual a "Carmen" o "Joaquin"
filtro_e=filtro_a[(filtro_a["Precio Venta"]>1000000) | (df["Vendedor"]=="Carmen") | (df["Vendedor"]=="Joaquín")]
filtro_e
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 0    2004-01-01     Parking  Alquiler     Lleida       291.0     2133903.0
# 1    2004-01-01       Local     Venta     Girona       185.0     1945424.0
# 2    2004-01-01     Oficina  Alquiler     Girona        82.0           NaN
# 7    2004-01-03     Oficina     Venta     Girona       235.0     2158475.0
# 8    2004-01-04        Piso  Alquiler     Lleida       108.0     1024380.0
# ...         ...         ...       ...        ...         ...           ...
# 3325 2007-04-25  Industrial  Alquiler  Barcelona       296.0     2078216.0
# 3328 2007-04-26        Piso     Venta  Barcelona       264.0     2517504.0
# 3331 2007-04-29     Oficina     Venta     Lleida       190.0     1031320.0
# 3332 2007-04-29  Industrial  Alquiler     Lleida       221.0     1450644.0
# 3336 2007-04-30     Parking     Venta     Lleida       254.0     2140712.0
#
#      Fecha Venta Vendedor
# 0     2004-06-19   Carmen
# ...

# %%
#Filtro f: Todos los registros que no sean de "Provincia":"Barcelona"
filtro_f=filtro_a[~(filtro_a["Provincia"]=="Barcelona")]
filtro_f
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 0    2004-01-01     Parking  Alquiler     Lleida       291.0     2133903.0
# 1    2004-01-01       Local     Venta     Girona       185.0     1945424.0
# 2    2004-01-01     Oficina  Alquiler     Girona        82.0           NaN
# 3    2004-01-02     Parking  Alquiler     Girona       285.0           NaN
# 4    2004-01-02       Suelo     Venta  Tarragona       152.0      185000.0
# ...         ...         ...       ...        ...         ...           ...
# 3331 2007-04-29     Oficina     Venta     Lleida       190.0     1031320.0
# 3332 2007-04-29  Industrial  Alquiler     Lleida       221.0     1450644.0
# 3333 2007-04-29        Piso  Alquiler     Girona        55.0      454080.0
# 3334 2007-04-30       Suelo     Venta  Tarragona        78.0      740688.0
# 3336 2007-04-30     Parking     Venta     Lleida       254.0     2140712.0
#
#      Fecha Venta Vendedor
# 0     2004-06-19   Carmen
# ...

# %%
#Comprobación filtro_f: no debe salir Barcelona
np.unique(filtro_f["Provincia"])
# Out:
# array(['Girona', 'Lleida', 'Tarragona'], dtype=object)

# %%
#Filtro g: Todos los registros que no sean de Operación: alquiler ni Tipo: oficina
filtro_g=filtro_a[~(filtro_a["Operación"]=="Alquiler") & ~(filtro_a["Tipo"]=="Oficina")]
filtro_g
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 1    2004-01-01       Local     Venta     Girona       185.0     1945424.0
# 4    2004-01-02       Suelo     Venta  Tarragona       152.0      185000.0
# 9    2004-01-04     Parking     Venta     Lleida       299.0     2042768.0
# 11   2004-01-04  Industrial     Venta     Girona       187.0      999328.0
# 12   2004-01-04     Parking     Venta  Barcelona         NaN     2937300.0
# ...         ...         ...       ...        ...         ...           ...
# 3328 2007-04-26        Piso     Venta  Barcelona       264.0     2517504.0
# 3329 2007-04-27     Parking     Venta  Barcelona        88.0      612568.0
# 3330 2007-04-27       Local     Venta     Girona       110.0      845790.0
# 3334 2007-04-30       Suelo     Venta  Tarragona        78.0      740688.0
# 3336 2007-04-30     Parking     Venta     Lleida       254.0     2140712.0
#
#      Fecha Venta Vendedor
# 1     2004-04-19    Pedro
# ...

# %%
#Conversión a archivos csv
filtro_a.to_csv("filtro_a.csv")
filtro_b.to_csv("filtro_b.csv")
filtro_c.to_csv("filtro_c.csv")
filtro_d.to_csv("filtro_d.csv")
filtro_e.to_csv("filtro_e.csv")
filtro_f.to_csv("filtro_f.csv")
filtro_g.to_csv("filtro_g.csv")
